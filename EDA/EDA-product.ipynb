# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
product = pd.read_csv('product.csv' , sep=';')

# %%
product.head()
# Out:
#   id deleted deleted_by_cascade                  created_at  \
# 0  2     NaN                  f  2023-03-26 15:53:58.466+01
# 1  3     NaN                  f  2023-03-26 21:04:12.461+01
# 2  4     NaN                  f   2023-03-26 21:04:44.98+01
# 3  5     NaN                  f  2023-03-26 21:05:41.351+01
# 4  6     NaN                  f  2023-03-26 21:11:53.982+01
#
#                    updated_at                               name  \
# 0   2023-03-26 21:05:52.57+01                       Extra Game 1
# 1   2023-03-27 13:57:28.43+01                         1 H ALL IN
# 2  2023-03-27 13:57:13.035+01                       game for Fit
# 3  2023-03-27 13:56:50.922+01                        EXTRA LASER
# 4  2023-03-27 13:55:48.056+01  Trampoline + Extra Game 1 1 heure
#
#                                          description is_game  duration  price  \
# 0                                       Extra Game 1       t       2.0    5.0
# 1  Trampoline + Extra Game 2 + Extra Game 1 pour ...       t       1.0   25.0
# 2                                      FIT une heure       t       1.0   20.0
# 3                                        EXTRA LASER       t       2.0    5.0
# 4             Pack Trampoline + Extra Game 1 1 heure       t       1.0   20.0
#
#                                                image  stock
# 0              media/products/IMGBN88506park1_xlv1mn    0.0
# 1                   media/products/1_H_ALL_IN_rcyrxc    0.0
# 2                   media/products/game_fit_1_h1vka2    0.0
# 3  media/products/Laserski-labirint-Maze-08-min-1...    0.0
# 4                      media/products/ninja_1_qvwbta    0.0

# %%
print(product.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  28 non-null     object
#  1   deleted             1 non-null      object
#  2   deleted_by_cascade  24 non-null     object
#  3   created_at          24 non-null     object
#  4   updated_at          23 non-null     object
#  5   name                24 non-null     object
#  6   description         23 non-null     object
#  7   is_game             22 non-null     object
#  8   duration            18 non-null     float64
#  9   price               22 non-null     float64
#  10  image               18 non-null     object
#  11  stock               22 non-null     float64
# dtypes: float64(3), object(9)
# memory usage: 2.8+ KB
# None

# %%
summary_stats = product.describe()

# %%
print(summary_stats)
# Out:
#         duration      price        stock
# count  18.000000  22.000000    22.000000
# mean    1.500000  20.227273  -409.590909
# std     0.514496  12.727667  1048.302967
# min     1.000000   5.000000 -4312.000000
# 25%     1.000000   7.000000     0.000000
# 50%     1.500000  20.000000     0.000000
# 75%     2.000000  27.250000     0.000000
# max     2.000000  50.000000     0.000000

# %%
# Check for missing values
print(product.isnull().sum())

# Check data types
print(product.dtypes)
# Out:
# id                     0
# deleted               27
# deleted_by_cascade     4
# created_at             4
# updated_at             5
# name                   4
# description            5
# is_game                6
# duration              10
# price                  6
# image                 10
# stock                  6
# dtype: int64
# id                     object
# deleted                object
# deleted_by_cascade     object
# created_at             object
# updated_at             object
# name                   object
# description            object
# is_game                object
# duration              float64
# price                 float64
# image                  object
# stock                 float64
# dtype: object

# %%
product.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# dtype: bool

# %%
# Histograms for numerical columns
product.hist(bins=50, figsize=(20,15))
plt.show()

# Box plots for numerical columns
# sns.boxplot(x='column_name', data=data)

# Scatter plots for relationships
# sns.scatterplot(x='column1', y='column2', data=data)

# Correlation heatmap
plt.figure(figsize=(20, 12))
corr_matrix = product.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#Correlation between variables
correlation_matrix = product.corr()

correlation_matrix
# Out:
#           duration     price     stock
# duration  1.000000 -0.034643       NaN
# price    -0.034643  1.000000  0.489711
# stock          NaN  0.489711  1.000000

# %%
# Selecting a subset of columns for the pair plot, feel free to adjust these
selected_columns = ['duration','price','stock']

# Generating the pair plot
sns.pairplot(product[selected_columns])
