# %% [markdown]
# import pandas as pd
# import matplotlib as plt
# import seaborn as sns
# import numpy as np
# import matplotlib.pyplot as plt
#
# import warnings
# warnings.filterwarnings('ignore')

# %%
payment = pd.read_csv('payment.csv')

# %%
payment.head()
# Out:
#    id                  created_at                  updated_at method  amount  \
# 0  45  2023-03-30 13:24:30.125+01  2023-03-30 13:24:30.125+01   cash    68.0
# 1  46  2023-03-30 13:40:55.219+01  2023-03-30 13:40:55.219+01   cash    68.0
# 2  47  2023-03-30 13:57:59.052+01  2023-03-30 13:57:59.052+01    tpe    23.0
# 3  48   2023-03-30 14:00:37.49+01   2023-03-30 14:00:37.49+01   cash    15.0
# 4  49  2023-03-30 14:13:39.377+01  2023-03-30 14:13:39.377+01    tpe    68.0
#
#    cheque_reference  order_id
# 0               NaN        59
# 1               NaN        60
# 2               NaN        61
# 3               NaN        62
# 4               NaN        64

# %%
print(payment.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29374 entries, 0 to 29373
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                29374 non-null  int64
#  1   created_at        29374 non-null  object
#  2   updated_at        29374 non-null  object
#  3   method            29374 non-null  object
#  4   amount            29374 non-null  float64
#  5   cheque_reference  0 non-null      float64
#  6   order_id          29374 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.6+ MB
# None

# %%
summary_stats = payment.describe()

# %%
print(summary_stats)
# Out:
#                  id        amount  cheque_reference      order_id
# count  29374.000000  29374.000000               0.0  29374.000000
# mean   14978.584531     57.262264               NaN  15009.085245
# std     8668.950493     60.335713               NaN   8675.031185
# min       45.000000    -50.000000               NaN     59.000000
# 25%     7466.250000     28.000000               NaN   7527.250000
# 50%    14907.500000     45.000000               NaN  14928.500000
# 75%    22463.750000     70.000000               NaN  22451.750000
# max    30135.000000   2720.000000               NaN  30250.000000

# %%
payment.shape
# Out:
# (29374, 7)

# %%
payment.columns
# Out:
# Index(['id', 'created_at', 'updated_at', 'method', 'amount',
#        'cheque_reference', 'order_id'],
#       dtype='object')

# %%
payment.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29369    False
# 29370    False
# 29371    False
# 29372    False
# 29373    False
# Length: 29374, dtype: bool

# %% [markdown]
# there's no duplication in all rows

# %%
for i in payment.columns :
    print(i," ",payment[i].unique())
# Out:
# id   [   45    46    47 ... 30133 30134 30135]
# created_at   ['2023-03-30 13:24:30.125+01' '2023-03-30 13:40:55.219+01'
#  '2023-03-30 13:57:59.052+01' ... '2023-11-07 12:46:04.001636+01'
#  '2023-11-07 12:57:57.501991+01' '2023-11-07 13:06:20.204707+01']
# updated_at   ['2023-03-30 13:24:30.125+01' '2023-03-30 13:40:55.219+01'
#  '2023-03-30 13:57:59.052+01' ... '2023-11-07 12:46:04.001661+01'
#  '2023-11-07 12:57:57.502014+01' '2023-11-07 13:06:20.204746+01']
# method   ['cash' 'tpe' 'cheque']
# amount   [ 6.80000e+01  2.30000e+01  1.50000e+01  4.00000e+01  8.70000e+01
#   4.50000e+01  1.12000e+02  1.85000e+02  2.90000e+01  3.40000e+01
#   7.90000e+01  1.36000e+02  6.00000e+01  6.30000e+01  2.04000e+02
#   1.02000e+02  7.00000e+01  1.70000e+02  5.00000e+01  1.78500e+02
#   1.10000e+02  9.30000e+01  2.00000e+01  1.50000e+02  1.00000e+01
#   1.95000e+02  4.90000e+01  1.80000e+01  2.50000e+01  8.40000e+01
#   5.50000e+01  3.00000e+01  8.00000e+01  2.60000e+01  1.30000e+01
# ...

# %%
plt.figure(figsize = (20,20))
dff=payment.corr()
sns.heatmap(dff, annot =True , fmt = ".1f", linewidth= 0.7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see here that the correlation has no meaning and there's no meaningfull correlation between it's variable
